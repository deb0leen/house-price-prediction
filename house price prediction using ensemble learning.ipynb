# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('clean_train.csv')

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave    NO      Reg
# 1             20       RL         80.0     9600   Pave    NO      Reg
# 2             60       RL         68.0    11250   Pave    NO      IR1
# 3             70       RL         60.0     9550   Pave    NO      IR1
# 4             60       RL         84.0    14260   Pave    NO      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1374          60       RL         62.0     7917   Pave    NO      Reg
# 1375          20       RL         85.0    13175   Pave    NO      Reg
# 1376          70       RL         66.0     9042   Pave    NO      Reg
# 1377          20       RL         68.0     9717   Pave    NO      Reg
# 1378          20       RL         75.0     9937   Pave    NO      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea  Fence  \
# ...

# %%
cat_cols = df.select_dtypes(include ='object').columns
num_cols = df.select_dtypes(include = np.number).columns

# %%
df.drop(['MiscFeature','MiscVal'],axis =1, inplace = True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for col in num_cols:
    sns.boxplot(x=df[col])
    plt.xticks(rotation =90)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
for col in cat_cols:
    sns.boxplot(x=df[col],y= df['SalePrice'])
    plt.xticks(rotation =90)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df_copy = df.copy()
corr_matrix = df_copy[df_copy.select_dtypes(include=np.number).columns].corr()
corr_matrix
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.220301 -0.136092     0.050092    -0.097027
# LotFrontage     -0.220301     1.000000  0.096486     0.181773    -0.055003
# LotArea         -0.136092     0.096486  1.000000     0.090016    -0.002869
# OverallQual      0.050092     0.181773  0.090016     1.000000    -0.136232
# OverallCond     -0.097027    -0.055003 -0.002869    -0.136232     1.000000
# YearBuilt        0.060041     0.036465 -0.005921     0.572082    -0.403602
# YearRemodAdd     0.036926     0.078981  0.002764     0.557772     0.048340
# MasVnrArea       0.034390     0.105703  0.095510     0.398334    -0.132515
# BsmtFinSF1      -0.067904     0.081660  0.210145     0.223690    -0.050818
# BsmtFinSF2      -0.079326    -0.011105  0.110011    -0.073166     0.038770
# BsmtUnfSF       -0.138829     0.155099 -0.009707     0.318552    -0.140730
# ...

# %%
corr_matrix['SalePrice'].sort_values(ascending = False)
# Out:
# SalePrice        1.000000
# OverallQual      0.787228
# GrLivArea        0.708172
# GarageCars       0.637095
# GarageArea       0.608405
# TotalBsmtSF      0.603583
# 1stFlrSF         0.594935
# FullBath         0.556550
# TotRmsAbvGrd     0.538309
# YearBuilt        0.507584
# YearRemodAdd     0.505434
# GarageYrBlt      0.486362
# MasVnrArea       0.463139
# Fireplaces       0.448877
# BsmtFinSF1       0.375563
# OpenPorchSF      0.333036
# 2ndFlrSF         0.313336
# WoodDeckSF       0.312631
# HalfBath         0.270721
# LotArea          0.252921
# BsmtFullBath     0.225988
# LotFrontage      0.213331
# BsmtUnfSF        0.213135
# BedroomAbvGr     0.164655
# ScreenPorch      0.099453
# PoolArea         0.091518
# MoSold           0.043749
# 3SsnPorch        0.039226
# LowQualFinSF    -0.008364
# BsmtFinSF2      -0.023243
# BsmtHalfBath    -0.025651
# YrSold          -0.026726
# MSSubClass      -0.077707
# OverallCond     -0.095278
# EnclosedPorch   -0.120164
# ...

# %%
df_copy['YearsNoConstruction'] = df_copy['YearRemodAdd'] - df_copy['YearBuilt']
print(df_copy['YearRemodAdd'].corr(df_copy['SalePrice']))
print(df_copy['YearBuilt'].corr(df_copy['SalePrice']))
print(df_copy['YearsNoConstruction'].corr(df_copy['SalePrice']))
# Out:
# 0.505434060859455
# 0.5075840635608162
# -0.1973011676171183

# %%
df_copy[df_copy['BsmtFinType1'] != df_copy['BsmtFinType2']][['BsmtFinType1','BsmtFinType2']]
# Out:
#      BsmtFinType1 BsmtFinType2
# 0             GLQ          Unf
# 1             ALQ          Unf
# 2             GLQ          Unf
# 3             ALQ          Unf
# 4             GLQ          Unf
# ...           ...          ...
# 1373          GLQ          Unf
# 1375          ALQ          Rec
# 1376          GLQ          Unf
# 1377          GLQ          Rec
# 1378          BLQ          LwQ
#
# [952 rows x 2 columns]

# %%
print(df_copy['BsmtFinSF1'].corr(df_copy['SalePrice']))
print(df_copy['BsmtFinSF2'].corr(df_copy['SalePrice']))
print(df_copy['TotalBsmtSF'].corr(df_copy['SalePrice']))
print(df_copy['BsmtUnfSF'].corr(df_copy['SalePrice']))
print((df_copy['BsmtUnfSF']/df_copy['TotalBsmtSF']).corr(df_copy['SalePrice']))
print(((df_copy['BsmtFinSF1']+df_copy['BsmtFinSF2'])/df_copy['TotalBsmtSF']).corr(df_copy['SalePrice']))
print((df_copy['BsmtFinSF1']/df_copy['TotalBsmtSF']).corr(df_copy['SalePrice']))
# Out:
# 0.3755627556460631
# -0.023242905914850127
# 0.6035834052193846
# 0.21313492312249646
# -0.09182037287340679
# 0.09182037287340676
# 0.1292365661362897

# %%
print(df_copy['2ndFlrSF'].corr(df_copy['SalePrice']))
print(df_copy['1stFlrSF'].corr(df_copy['SalePrice']))
print((df_copy['2ndFlrSF']+df_copy['1stFlrSF']).corr(df_copy['SalePrice']))
# Out:
# 0.3133355898234006
# 0.5949352701531119
# 0.7123049701158124

# %%
print((df_copy['GrLivArea']+df_copy['TotalBsmtSF']).corr(df_copy['SalePrice']))
print(df_copy['GrLivArea'].corr(df_copy['SalePrice']))
# Out:
# 0.7765922603693934
# 0.7081721139540177

# %%
print((df_copy['BsmtFullBath']+df_copy['FullBath']+df_copy['BsmtHalfBath']+df_copy['HalfBath']).corr(df_copy['SalePrice']))
print((df_copy['BsmtHalfBath']+df_copy['HalfBath']).corr(df_copy['SalePrice']))
print((df_copy['BsmtFullBath']+df_copy['FullBath']).corr(df_copy['SalePrice']))
print((df_copy['BsmtFullBath']+df_copy['BsmtHalfBath']).corr(df_copy['SalePrice']))
print((df_copy['FullBath']+df_copy['HalfBath']).corr(df_copy['SalePrice']))
# Out:
# 0.6088007097119743
# 0.23475518920900806
# 0.5847855287459479
# 0.20671852569939084
# 0.5581989428193089

# %%
print(df_copy['TotRmsAbvGrd'].corr(df_copy['SalePrice']))
print((df_copy['KitchenAbvGr']/df_copy['TotRmsAbvGrd']).corr(df_copy['SalePrice']))
print(df_copy['KitchenAbvGr'].corr(df_copy['SalePrice']))
print(df_copy['BedroomAbvGr'].corr(df_copy['SalePrice']))
print((df_copy['BedroomAbvGr']/df_copy['TotRmsAbvGrd']).corr(df_copy['SalePrice']))
# Out:
# 0.5383091241374475
# -0.5157246340286833
# -0.13557396150699433
# 0.1646549492106764
# -0.34754633202871593

# %%
print((df_copy['YrSold']-df_copy['YearBuilt']).corr(df_copy['SalePrice']))
print((df_copy['YearRemodAdd']-df_copy['YearBuilt']).corr(df_copy['SalePrice']))
# Out:
# -0.5081170918651994
# -0.1973011676171183

# %%
anova_test_data = df_copy[~(df['SalePrice'].isnull())]

# %%
from scipy.stats import f_oneway

# %%
for col in anova_test_data.select_dtypes(include = 'object').columns:
    CategoryGroup = anova_test_data.groupby(col)['SalePrice'].apply(list)
    AnovaResults = f_oneway(*CategoryGroup)
    if AnovaResults[1] < 0.05:
        print('P-Value for Anova is: ', col, AnovaResults[1], 'Correlated')
    else:
        print('P-Value for Anova is: ', col, AnovaResults[1], 'Not Correlated')
# Out:
# P-Value for Anova is:  MSZoning 7.042720535175949e-30 Correlated
# P-Value for Anova is:  Street 0.13340090962210818 Not Correlated
# P-Value for Anova is:  Alley 1.1428704629936157e-06 Correlated
# P-Value for Anova is:  LotShape 7.587156555665221e-23 Correlated
# P-Value for Anova is:  LandContour 2.7449799165760116e-08 Correlated
# P-Value for Anova is:  Utilities 0.5437963424887088 Not Correlated
# P-Value for Anova is:  LotConfig 3.2135169613023594e-05 Correlated
# P-Value for Anova is:  LandSlope 0.05575797131404581 Not Correlated
# P-Value for Anova is:  Neighborhood 4.386519691953951e-202 Correlated
# P-Value for Anova is:  Condition1 9.538598468258657e-07 Correlated
# P-Value for Anova is:  Condition2 0.054346385490071786 Not Correlated
# P-Value for Anova is:  BldgType 1.0686223322313858e-08 Correlated
# P-Value for Anova is:  HouseStyle 4.225868258429076e-22 Correlated
# P-Value for Anova is:  RoofStyle 2.6139306305148553e-15 Correlated
# ...

# %%
df_copy['TotalFlrSF'] = df_copy['2ndFlrSF']+df_copy['1stFlrSF']

# %%
df_copy['TotalFlrSF'].corr(df_copy['GrLivArea'])
# Out:
# 0.9970095494156754

# %%
df_copy['TotalArea'] = df_copy['GrLivArea'] + df_copy['TotalBsmtSF']

# %%
df_copy['NumBaths'] = df_copy['BsmtFullBath']+df_copy['FullBath']+df_copy['BsmtHalfBath']+df_copy['HalfBath']

# %%
df_copy['Kitchen/TotalRooms'] = df_copy['KitchenAbvGr']/df_copy['TotRmsAbvGrd']
df_copy['BedroomAbvGr/TotalRooms'] = df_copy['BedroomAbvGr']/df_copy['TotRmsAbvGrd']

# %%
df_copy['AgeSold'] = df_copy['YrSold']-df_copy['YearBuilt']

# %%
df_copy[df_copy.select_dtypes(include=np.number).columns].corr()['SalePrice'].sort_values(ascending = False)
# Out:
# SalePrice                  1.000000
# OverallQual                0.787228
# TotalArea                  0.776592
# TotalFlrSF                 0.712305
# GrLivArea                  0.708172
# GarageCars                 0.637095
# NumBaths                   0.608801
# GarageArea                 0.608405
# TotalBsmtSF                0.603583
# 1stFlrSF                   0.594935
# FullBath                   0.556550
# TotRmsAbvGrd               0.538309
# YearBuilt                  0.507584
# YearRemodAdd               0.505434
# GarageYrBlt                0.486362
# MasVnrArea                 0.463139
# Fireplaces                 0.448877
# BsmtFinSF1                 0.375563
# OpenPorchSF                0.333036
# 2ndFlrSF                   0.313336
# WoodDeckSF                 0.312631
# HalfBath                   0.270721
# LotArea                    0.252921
# BsmtFullBath               0.225988
# LotFrontage                0.213331
# BsmtUnfSF                  0.213135
# ...

# %%
df['TotalFlrSF'] = df['2ndFlrSF']+df['1stFlrSF']

# %%
df['TotalArea'] = df['GrLivArea'] + df['TotalBsmtSF']

# %%
df['NumBaths'] = df['BsmtFullBath']+df['FullBath']+df['BsmtHalfBath']+df['HalfBath']

# %%
df['AgeSold'] = df['YrSold']-df['YearBuilt']

# %%
df.drop(['Condition2','BsmtFinSF2','1stFlrSF','2ndFlrSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath',
             'GarageArea','Street','Utilities','LandSlope','KitchenAbvGr','MoSold','YrSold','EnclosedPorch',
        'MSSubClass','LowQualFinSF','3SsnPorch','PoolArea'],axis =1, inplace = True)

# %%
df[df.select_dtypes(include=np.number).columns].corr()['SalePrice'].sort_values(ascending = False)
# Out:
# SalePrice       1.000000
# OverallQual     0.787228
# TotalArea       0.776592
# TotalFlrSF      0.712305
# GarageCars      0.637095
# NumBaths        0.608801
# TotalBsmtSF     0.603583
# TotRmsAbvGrd    0.538309
# YearBuilt       0.507584
# YearRemodAdd    0.505434
# GarageYrBlt     0.486362
# MasVnrArea      0.463139
# Fireplaces      0.448877
# BsmtFinSF1      0.375563
# OpenPorchSF     0.333036
# WoodDeckSF      0.312631
# LotArea         0.252921
# LotFrontage     0.213331
# BsmtUnfSF       0.213135
# BedroomAbvGr    0.164655
# ScreenPorch     0.099453
# OverallCond    -0.095278
# AgeSold        -0.508117
# Name: SalePrice, dtype: float64

# %%
sns.scatterplot(x='OverallCond', y='SalePrice',hue = 'OverallQual',data =df)
plt.show()

# %%
df = pd.get_dummies(df)

# %%
df['SalePrice'].describe()
# Out:
# count      1379.00000
# mean     185479.51124
# std       79023.89060
# min       35311.00000
# 25%      134000.00000
# 50%      167500.00000
# 75%      217750.00000
# max      755000.00000
# Name: SalePrice, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

X = df.drop(['SalePrice'], axis=1)
Y = df['SalePrice']

# Split the training set into
# training and validation set
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(X_train, Y_train)
Y_pred = model_RFR.predict(X_valid)

mean_absolute_percentage_error(Y_valid, Y_pred)
# Out:
# 0.1004696853653077

# %%
from sklearn.linear_model import LinearRegression

model_LR = LinearRegression()
model_LR.fit(X_train, Y_train)
Y_pred = model_LR.predict(X_valid)

print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.09968139429826962

# %%
from catboost import CatBoostRegressor
cb_model = CatBoostRegressor()
cb_model.fit(X_train, Y_train)
preds = cb_model.predict(X_valid)

cb_r2_score=r2_score(Y_valid, preds)
cb_r2_score
# Out:
# Learning rate set to 0.041582
# 0:	learn: 77788.2447444	total: 2.71ms	remaining: 2.7s
# 1:	learn: 75757.7450761	total: 5.08ms	remaining: 2.54s
# 2:	learn: 73762.4989137	total: 7.25ms	remaining: 2.41s
# 3:	learn: 71920.8637088	total: 9.51ms	remaining: 2.37s
# 4:	learn: 70088.5456008	total: 11.9ms	remaining: 2.36s
# 5:	learn: 68301.4051777	total: 14.1ms	remaining: 2.33s
# 6:	learn: 66609.4561357	total: 16.3ms	remaining: 2.32s
# 7:	learn: 64980.4271646	total: 18.8ms	remaining: 2.33s
# 8:	learn: 63337.1635030	total: 21.1ms	remaining: 2.32s
# 9:	learn: 61902.9288875	total: 23.3ms	remaining: 2.31s
# 10:	learn: 60505.6142013	total: 25.6ms	remaining: 2.3s
# 11:	learn: 59248.1764577	total: 27.7ms	remaining: 2.28s
# 12:	learn: 57893.3611757	total: 29.9ms	remaining: 2.27s
# 13:	learn: 56631.4490608	total: 32ms	remaining: 2.26s
# 14:	learn: 55449.7995838	total: 34.4ms	remaining: 2.25s
# 15:	learn: 54249.5862517	total: 36.7ms	remaining: 2.25s
# ...

# %%
from sklearn.metrics import r2_score

# %%
pip install catboost
# Out:
# ...
#                                               0.0/101.0 MB ? eta -:--:--
#                                               0.0/101.0 MB ? eta -:--:--
#                                               0.0/101.0 MB ? eta -:--:--
#                                               0.0/101.0 MB ? eta -:--:--
#                                             0.0/101.0 MB 163.8 kB/s eta 0:10:17
#                                             0.0/101.0 MB 163.8 kB/s eta 0:10:17
#                                             0.0/101.0 MB 151.3 kB/s eta 0:11:08
#                                             0.1/101.0 MB 192.5 kB/s eta 0:08:45
#                                             0.1/101.0 MB 196.3 kB/s eta 0:08:35
#                                             0.1/101.0 MB 196.3 kB/s eta 0:08:35
#                                             0.1/101.0 MB 196.3 kB/s eta 0:08:35
#                                             0.1/101.0 MB 196.3 kB/s eta 0:08:35
# ...
